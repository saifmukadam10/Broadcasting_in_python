# %% [markdown]
# <a href="https://colab.research.google.com/github/saifmukadam10/Broadcasting_in_python/blob/main/Broadcasting_In_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
a = np.array([[56.23, 0.0, 4.4, 68.00],[1.2, 104.00, 58.00, 8.8], [1.8,135.5, 99.0, 9.9]])
print(a)
# Out:
# [[ 56.23   0.     4.4   68.  ]
#  [  1.2  104.    58.     8.8 ]
#  [  1.8  135.5   99.     9.9 ]]

# %%
cal = a.sum(axis=0)
print (cal)
# Out:
# [ 59.23 239.5  161.4   86.7 ]

# %%
percentage = 100*a/cal.reshape(1,4)
print(percentage)
# Out:
# [[94.93499916  0.          2.72614622 78.43137255]
#  [ 2.02600034 43.42379958 35.93556382 10.14994233]
#  [ 3.03900051 56.57620042 61.33828996 11.41868512]]
